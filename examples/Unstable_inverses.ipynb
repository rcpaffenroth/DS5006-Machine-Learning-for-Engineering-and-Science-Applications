# %%
import numpy as np

# %%
X = np.matrix([[1,6],[1,6],[1,6]])
X

# %%
M = X.T @ X
M

# %%
np.linalg.inv(M)

# %%
np.linalg.eig(M)

# %%
X = np.matrix([[1, 6.000001],
               [1, 6.000002],
               [1, 5.999999]])
M = X.T @ X
Mi=np.linalg.inv(M)
np.linalg.eig(M)

# %%
M @ Mi
